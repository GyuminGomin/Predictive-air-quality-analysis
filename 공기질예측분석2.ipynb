# %% [markdown]
# # 그래프 5개 비교

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import timedelta, datetime
from matplotlib import font_manager, rc

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['figure.figsize'] = [25,15]
plt.rcParams['font.size'] = 25

# %% [markdown]
# # 01.01~01.15 PM2.5

# %%
arim_data_2 = pd.read_csv('./OA200_2/OA2002_01.01~01.15.csv')
arim_data_1 = pd.read_csv('./OA200_1/OA2001_01.01~01.15.csv')
airKorea_data_sangbong = pd.read_csv('./AirKorea_상봉동/AirKorea_01.01~01.15.csv')
airKorea_data_sangdae = pd.read_csv('./AirKorea_상대동/AirKorea_01.01~01.15.csv')
airKorea_data_daean = pd.read_csv('./AirKorea_대안동/AirKorea_01.01~01.15.csv')

# arim_data 1.1~1.15 Hour

arim_data_1['reg_date'] = arim_data_1.reg_date.apply(pd.to_datetime)
arim_data_2['reg_date'] = arim_data_2.reg_date.apply(pd.to_datetime)

# 날짜별 그룹화하고 그 날짜별 시간대별로 다시 그룹화하여 평균값 계산
arim_data_1_avg = arim_data_1.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()
arim_data_2_avg = arim_data_2.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()


# airKorea_data 1.1~1.15 Hour
airKorea_data_sangbong['date'] = airKorea_data_sangbong.date.apply(pd.to_datetime)
airKorea_data_sangdae['date'] = airKorea_data_sangdae.date.apply(pd.to_datetime)
airKorea_data_daean['date'] = airKorea_data_daean.date.apply(pd.to_datetime)


# 그래프 5개 비교
plt.plot(airKorea_data_sangbong.date, airKorea_data_sangbong.pm25, color="red", linewidth="5")
plt.plot(airKorea_data_sangdae.date, airKorea_data_sangdae.pm25, color="blue", linewidth="5")
plt.plot(airKorea_data_daean.date, airKorea_data_daean.pm25, color='green', linewidth="10")
plt.plot(arim_data_1_avg.index, arim_data_1_avg.pm25, color='purple', linewidth="5")
plt.plot(arim_data_2_avg.index, arim_data_2_avg.pm25, color='black', linewidth="5")
plt.xlabel('Hour')
plt.ylabel('pm2.5')
plt.legend(('상봉동','상대동','대안동','OA200_1','OA200_2'))
plt.title('1.1~1.15 Hour comparison')
plt.show()

# %% [markdown]
# # 01.01~01.15 PM10

# %%
arim_data_2 = pd.read_csv('./OA200_2/OA2002_01.01~01.15.csv')
arim_data_1 = pd.read_csv('./OA200_1/OA2001_01.01~01.15.csv')
airKorea_data_sangbong = pd.read_csv('./AirKorea_상봉동/AirKorea_01.01~01.15.csv')
airKorea_data_sangdae = pd.read_csv('./AirKorea_상대동/AirKorea_01.01~01.15.csv')
airKorea_data_daean = pd.read_csv('./AirKorea_대안동/AirKorea_01.01~01.15.csv')

# arim_data 1.1~1.15 Hour

arim_data_1['reg_date'] = arim_data_1.reg_date.apply(pd.to_datetime)
arim_data_2['reg_date'] = arim_data_2.reg_date.apply(pd.to_datetime)

# 날짜별 그룹화하고 그 날짜별 시간대별로 다시 그룹화하여 평균값 계산
arim_data_1_avg = arim_data_1.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()
arim_data_2_avg = arim_data_2.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()


# airKorea_data 1.1~1.15 Hour
airKorea_data_sangbong['date'] = airKorea_data_sangbong.date.apply(pd.to_datetime)
airKorea_data_sangdae['date'] = airKorea_data_sangdae.date.apply(pd.to_datetime)
airKorea_data_daean['date'] = airKorea_data_daean.date.apply(pd.to_datetime)


# 그래프 5개 비교
plt.plot(airKorea_data_sangbong.date, airKorea_data_sangbong.pm10, color="red", linewidth="5")
plt.plot(airKorea_data_sangdae.date, airKorea_data_sangdae.pm10, color="blue", linewidth="5")
plt.plot(airKorea_data_daean.date, airKorea_data_daean.pm10, color='green', linewidth="10")
plt.plot(arim_data_1_avg.index, arim_data_1_avg.pm10, color='purple', linewidth="5")
plt.plot(arim_data_2_avg.index, arim_data_2_avg.pm10, color='black', linewidth="5")
plt.xlabel('Hour')
plt.ylabel('pm10')
plt.legend(('상봉동','상대동','대안동','OA200_1','OA200_2'))
plt.title('1.1~1.15 Hour comparison')
plt.show()

# %% [markdown]
# # 01.16~01.31 PM2.5

# %%
arim_data_2 = pd.read_csv('./OA200_2/OA2002_01.16~01.31.csv')
arim_data_1 = pd.read_csv('./OA200_1/OA2001_01.16~01.31.csv')
airKorea_data_sangbong = pd.read_csv('./AirKorea_상봉동/AirKorea_01.16~01.31.csv')
airKorea_data_sangdae = pd.read_csv('./AirKorea_상대동/AirKorea_01.16~01.31.csv')
airKorea_data_daean = pd.read_csv('./AirKorea_대안동/AirKorea_01.16~01.31.csv')

# arim_data 1.16~1.31 Hour

arim_data_1['reg_date'] = arim_data_1.reg_date.apply(pd.to_datetime)
arim_data_2['reg_date'] = arim_data_2.reg_date.apply(pd.to_datetime)

# 날짜별 그룹화하고 그 날짜별 시간대별로 다시 그룹화하여 평균값 계산
arim_data_1_avg = arim_data_1.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()
arim_data_2_avg = arim_data_2.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()


# airKorea_data 1.16~1.31 Hour
airKorea_data_sangbong['date'] = airKorea_data_sangbong.date.apply(pd.to_datetime)
airKorea_data_sangdae['date'] = airKorea_data_sangdae.date.apply(pd.to_datetime)
airKorea_data_daean['date'] = airKorea_data_daean.date.apply(pd.to_datetime)


# 그래프 5개 비교
plt.plot(airKorea_data_sangbong.date, airKorea_data_sangbong.pm25, color="red", linewidth="5")
plt.plot(airKorea_data_sangdae.date, airKorea_data_sangdae.pm25, color="blue", linewidth="5")
plt.plot(airKorea_data_daean.date, airKorea_data_daean.pm25, color='green', linewidth="10")
plt.plot(arim_data_1_avg.index, arim_data_1_avg.pm25, color='purple', linewidth="5")
plt.plot(arim_data_2_avg.index, arim_data_2_avg.pm25, color='black', linewidth="5")
plt.xlabel('Hour')
plt.ylabel('pm2.5')
plt.legend(('상봉동','상대동','대안동','OA200_1','OA200_2'))
plt.title('1.16~1.31 Hour comparison')
plt.show()

# %% [markdown]
# # 01.16~01.31 PM10

# %%
arim_data_2 = pd.read_csv('./OA200_2/OA2002_01.16~01.31.csv')
arim_data_1 = pd.read_csv('./OA200_1/OA2001_01.16~01.31.csv')
airKorea_data_sangbong = pd.read_csv('./AirKorea_상봉동/AirKorea_01.16~01.31.csv')
airKorea_data_sangdae = pd.read_csv('./AirKorea_상대동/AirKorea_01.16~01.31.csv')
airKorea_data_daean = pd.read_csv('./AirKorea_대안동/AirKorea_01.16~01.31.csv')

# arim_data 1.16~1.31 Hour

arim_data_1['reg_date'] = arim_data_1.reg_date.apply(pd.to_datetime)
arim_data_2['reg_date'] = arim_data_2.reg_date.apply(pd.to_datetime)

# 날짜별 그룹화하고 그 날짜별 시간대별로 다시 그룹화하여 평균값 계산
arim_data_1_avg = arim_data_1.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()
arim_data_2_avg = arim_data_2.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()


# airKorea_data 1.16~1.31 Hour
airKorea_data_sangbong['date'] = airKorea_data_sangbong.date.apply(pd.to_datetime)
airKorea_data_sangdae['date'] = airKorea_data_sangdae.date.apply(pd.to_datetime)
airKorea_data_daean['date'] = airKorea_data_daean.date.apply(pd.to_datetime)


# 그래프 5개 비교
plt.plot(airKorea_data_sangbong.date, airKorea_data_sangbong.pm10, color="red", linewidth="5")
plt.plot(airKorea_data_sangdae.date, airKorea_data_sangdae.pm10, color="blue", linewidth="5")
plt.plot(airKorea_data_daean.date, airKorea_data_daean.pm10, color='green', linewidth="10")
plt.plot(arim_data_1_avg.index, arim_data_1_avg.pm10, color='purple', linewidth="5")
plt.plot(arim_data_2_avg.index, arim_data_2_avg.pm10, color='black', linewidth="5")
plt.xlabel('Hour')
plt.ylabel('pm10')
plt.legend(('상봉동','상대동','대안동','OA200_1','OA200_2'))
plt.title('1.16~1.31 Hour comparison')
plt.show()

# %%
arim_data_2 = pd.read_csv('./OA200_2/OA2002_02.01~02.15.csv')
arim_data_1 = pd.read_csv('./OA200_1/OA2001_02.01~02.15.csv')
airKorea_data_sangbong = pd.read_csv('./AirKorea_상봉동/AirKorea_02.01~02.15.csv')
airKorea_data_sangdae = pd.read_csv('./AirKorea_상대동/AirKorea_02.01~02.15.csv')
airKorea_data_daean = pd.read_csv('./AirKorea_대안동/AirKorea_02.01~02.15.csv')

# arim_data 1.1~1.15 Hour

arim_data_1['reg_date'] = arim_data_1.reg_date.apply(pd.to_datetime)
arim_data_2['reg_date'] = arim_data_2.reg_date.apply(pd.to_datetime)

# 날짜별 그룹화하고 그 날짜별 시간대별로 다시 그룹화하여 평균값 계산
arim_data_1_avg = arim_data_1.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()
arim_data_2_avg = arim_data_2.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()


# airKorea_data 1.1~1.15 Hour
airKorea_data_sangbong['date'] = airKorea_data_sangbong.date.apply(pd.to_datetime)
airKorea_data_sangdae['date'] = airKorea_data_sangdae.date.apply(pd.to_datetime)
airKorea_data_daean['date'] = airKorea_data_daean.date.apply(pd.to_datetime)


# 그래프 5개 비교
plt.plot(airKorea_data_sangbong.date, airKorea_data_sangbong.pm25, color="red", linewidth="5")
plt.plot(airKorea_data_sangdae.date, airKorea_data_sangdae.pm25, color="blue", linewidth="5")
plt.plot(airKorea_data_daean.date, airKorea_data_daean.pm25, color='green', linewidth="10")
plt.plot(arim_data_1_avg.index, arim_data_1_avg.pm25, color='purple', linewidth="5")
plt.plot(arim_data_2_avg.index, arim_data_2_avg.pm25, color='black', linewidth="5")
plt.xlabel('Hour')
plt.ylabel('pm2.5')
plt.legend(('상봉동','상대동','대안동','OA200_1','OA200_2'))
plt.title('2.1~2.15 Hour comparison')
plt.show()

# %%
arim_data_2 = pd.read_csv('./OA200_2/OA2002_02.16~02.28.csv')
arim_data_1 = pd.read_csv('./OA200_1/OA2001_02.16~02.28.csv')
airKorea_data_sangbong = pd.read_csv('./AirKorea_상봉동/AirKorea_02.16~02.28.csv')
airKorea_data_sangdae = pd.read_csv('./AirKorea_상대동/AirKorea_02.16~02.28.csv')
airKorea_data_daean = pd.read_csv('./AirKorea_대안동/AirKorea_02.16~02.28.csv')

# arim_data 1.1~1.15 Hour

arim_data_1['reg_date'] = arim_data_1.reg_date.apply(pd.to_datetime)
arim_data_2['reg_date'] = arim_data_2.reg_date.apply(pd.to_datetime)

# 날짜별 그룹화하고 그 날짜별 시간대별로 다시 그룹화하여 평균값 계산
arim_data_1_avg = arim_data_1.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()
arim_data_2_avg = arim_data_2.groupby([pd.Grouper(key='reg_date', freq='H')]).mean()


# airKorea_data 1.1~1.15 Hour
airKorea_data_sangbong['date'] = airKorea_data_sangbong.date.apply(pd.to_datetime)
airKorea_data_sangdae['date'] = airKorea_data_sangdae.date.apply(pd.to_datetime)
airKorea_data_daean['date'] = airKorea_data_daean.date.apply(pd.to_datetime)


# 그래프 5개 비교
plt.plot(airKorea_data_sangbong.date, airKorea_data_sangbong.pm25, color="red", linewidth="5")
plt.plot(airKorea_data_sangdae.date, airKorea_data_sangdae.pm25, color="blue", linewidth="5")
plt.plot(airKorea_data_daean.date, airKorea_data_daean.pm25, color='green', linewidth="10")
plt.plot(arim_data_1_avg.index, arim_data_1_avg.pm25, color='purple', linewidth="5")
plt.plot(arim_data_2_avg.index, arim_data_2_avg.pm25, color='black', linewidth="5")
plt.xlabel('Hour')
plt.ylabel('pm2.5')
plt.legend(('상봉동','상대동','대안동','OA200_1','OA200_2'))
plt.title('2.16~2.28 Hour comparison')
plt.show()
